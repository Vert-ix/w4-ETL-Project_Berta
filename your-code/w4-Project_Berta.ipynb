# %%
import pandas as pd

# %%
import json

# %% [markdown]
# ### Tabla satisfaction

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
# Renombrar columnas

new_cols = [c.lower().rstrip().lstrip().replace(' ', '_') for c in data.columns]
new_cols
# Out:
# ['unnamed:_0',
#  'id',
#  'gender',
#  'customer_type',
#  'age',
#  'type_of_travel',
#  'class',
#  'flight_distance',
#  'inflight_wifi_service',
#  'departure/arrival_time_convenient',
#  'ease_of_online_booking',
#  'gate_location',
#  'food_and_drink',
#  'online_boarding',
#  'seat_comfort',
#  'inflight_entertainment',
#  'on-board_service',
#  'leg_room_service',
#  'baggage_handling',
#  'checkin_service',
#  'inflight_service',
#  'cleanliness',
#  'departure_delay_in_minutes',
#  'arrival_delay_in_minutes',
#  'satisfaction']

# %%
dict(zip(data.columns, new_cols))
# Out:
# {'Unnamed: 0': 'unnamed:_0',
#  'id': 'id',
#  'Gender': 'gender',
#  'Customer Type': 'customer_type',
#  'Age': 'age',
#  'Type of Travel': 'type_of_travel',
#  'Class': 'class',
#  'Flight Distance': 'flight_distance',
#  'Inflight wifi service': 'inflight_wifi_service',
#  'Departure/Arrival time convenient': 'departure/arrival_time_convenient',
#  'Ease of Online booking': 'ease_of_online_booking',
#  'Gate location': 'gate_location',
#  'Food and drink': 'food_and_drink',
#  'Online boarding': 'online_boarding',
#  'Seat comfort': 'seat_comfort',
#  'Inflight entertainment': 'inflight_entertainment',
#  'On-board service': 'on-board_service',
#  'Leg room service': 'leg_room_service',
#  'Baggage handling': 'baggage_handling',
#  'Checkin service': 'checkin_service',
#  'Inflight service': 'inflight_service',
#  'Cleanliness': 'cleanliness',
#  'Departure Delay in Minutes': 'departure_delay_in_minutes',
#  'Arrival Delay in Minutes': 'arrival_delay_in_minutes',
# ...

# %%
data = data.rename(columns={k:v for k,v in zip(data.columns, new_cols)})

# %%
data.head()
# Out:
#    unnamed:_0      id  gender      customer_type  age   type_of_travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       class  flight_distance  inflight_wifi_service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    departure/arrival_time_convenient  ...  inflight_entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
nan_cols = data.isnull().sum()
nan_cols[nan_cols>0]
# Out:
# arrival_delay_in_minutes    310
# dtype: int64

# %%
data.shape
# Out:
# (103904, 25)

# %%
# Borrado de valores nulos procedentes de la columna arrival_delay_in_minutes.

no_local = data[data.arrival_delay_in_minutes.isnull()].index
data.drop(no_local, axis=0, inplace=True)

# %%
data['class'].value_counts()
# Out:
# Business    49533
# Eco         46593
# Eco Plus     7468
# Name: class, dtype: int64

# %%
data.drop(['unnamed:_0'], axis=1, inplace = True)

# %%
data.drop(['leg_room_service'], axis=1, inplace = True)

# %%
data.columns.unique()
# Out:
# Index(['id', 'gender', 'customer_type', 'age', 'type_of_travel', 'class',
#        'flight_distance', 'inflight_wifi_service',
#        'departure/arrival_time_convenient', 'ease_of_online_booking',
#        'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#        'inflight_entertainment', 'on-board_service', 'baggage_handling',
#        'checkin_service', 'inflight_service', 'cleanliness',
#        'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.to_csv('train_clean.csv', index=False)

# %% [markdown]
# ###  Tabla Aena

# %%
aena = pd.read_excel('Vuelos.xlsx')

# %%
aena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39102 entries, 0 to 39101
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   flightNumber      39102 non-null  object
#  1   plane             39102 non-null  object
#  2   dep_date          39102 non-null  object
#  3   dep_time          39102 non-null  object
#  4   dep_airport_name  39102 non-null  object
#  5   dep_airport_code  39102 non-null  object
#  6   dep_terminal      39102 non-null  object
#  7   dep_status        39102 non-null  object
#  8   dep_weather_min   39102 non-null  object
#  9   dep_weather_max   39102 non-null  object
#  10  dep_weather_desc  39102 non-null  object
#  11  dep_counter       39102 non-null  object
#  12  dep_door          39102 non-null  object
#  13  arr_date          39102 non-null  object
#  14  arr_time          39102 non-null  object
#  15  arr_airport_name  39102 non-null  object
# ...

# %%
aena.head()
# Out:
#   flightNumber plane             dep_date  dep_time        dep_airport_name  \
# 0       HTY134   AWH  2018-04-13 00:00:00  10:00:00  ALGECIRAS / HELIPUERTO
# 1       HTY110   AWH  2018-04-13 00:00:00  14:15:00                   CEUTA
# 2       HTY112   AWH  2018-04-13 00:00:00  15:05:00  ALGECIRAS / HELIPUERTO
# 3       HTY114   AWH  2018-04-13 00:00:00  15:35:00  ALGECIRAS / HELIPUERTO
# 4       HTY138   AWH  2018-04-13 00:00:00  18:45:00  ALGECIRAS / HELIPUERTO
#
#   dep_airport_code dep_terminal                         dep_status  \
# 0              AEI            -  El vuelo ha despegado a las 10:03
# 1              JCU            -       Llegada prevista a las 14:15
# 2              AEI            -        Salida prevista a las 15:10
# 3              AEI            -        Salida prevista a las 15:40
# 4              AEI            -        Salida prevista a las 18:50
#
#   dep_weather_min dep_weather_max  ...        arr_airport_name  \
# ...

# %%
# Borrar columnas

aena.drop(['timestamp'], axis=1, inplace = True)

# %%
aena.drop(['arr_belt'], axis=1, inplace = True)

# %%
aena.drop(['arr_room'], axis=1, inplace = True)

# %%
aena.drop(['dep_counter'], axis=1, inplace = True)

# %%
aena.drop(['dep_door'], axis=1, inplace = True)

# %%
aena.drop(['dep_terminal'], axis=1, inplace = True)

# %%
aena.drop(['arr_terminal'], axis=1, inplace = True)

# %%
aena.head()
# Out:
#   flightNumber plane             dep_date  dep_time        dep_airport_name  \
# 0       HTY134   AWH  2018-04-13 00:00:00  10:00:00  ALGECIRAS / HELIPUERTO
# 1       HTY110   AWH  2018-04-13 00:00:00  14:15:00                   CEUTA
# 2       HTY112   AWH  2018-04-13 00:00:00  15:05:00  ALGECIRAS / HELIPUERTO
# 3       HTY114   AWH  2018-04-13 00:00:00  15:35:00  ALGECIRAS / HELIPUERTO
# 4       HTY138   AWH  2018-04-13 00:00:00  18:45:00  ALGECIRAS / HELIPUERTO
#
#   dep_airport_code                         dep_status dep_weather_min  \
# 0              AEI  El vuelo ha despegado a las 10:03               9
# 1              JCU       Llegada prevista a las 14:15              11
# 2              AEI        Salida prevista a las 15:10               9
# 3              AEI        Salida prevista a las 15:40               9
# 4              AEI        Salida prevista a las 18:50               9
#
#   dep_weather_max     dep_weather_desc             arr_date  arr_time  \
# ...

# %%
aena['dep_airport_name'].value_counts()
# Out:
# MADRID-BARAJAS ADOLFO SUÁREZ    4083
# BARCELONA-EL PRAT               3098
# TENERIFE NORTE                  2819
# GRAN CANARIA                    2198
# PALMA DE MALLORCA               2091
# MALAGA-COSTA DEL SOL            1596
# LA PALMA                        1473
# LANZAROTE                       1341
# SEVILLA                         1315
# FUERTEVENTURA                   1301
# ALICANTE-ELCHE                  1278
# VALENCIA                        1219
# TENERIFE SUR                    1147
# GIRONA - COSTA BRAVA            1145
# SANTIAGO                        1104
# IBIZA                           1096
# MENORCA                         1045
# BILBAO                          1036
# MURCIA-SAN JAVIER                791
# GRANADA-JAÉN F.G.L.              775
# ASTURIAS                         773
# ALMERIA                          749
# JEREZ DE LA FRONTERA             625
# SANTANDER-SEVE BALLESTEROS       591
# MELILLA                          577
# ...

# %%
aena['id_aeropuerto']=''

# %%
aena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39102 entries, 0 to 39101
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   flightNumber      39102 non-null  object
#  1   plane             39102 non-null  object
#  2   dep_date          39102 non-null  object
#  3   dep_time          39102 non-null  object
#  4   dep_airport_name  39102 non-null  object
#  5   dep_airport_code  39102 non-null  object
#  6   dep_status        39102 non-null  object
#  7   dep_weather_min   39102 non-null  object
#  8   dep_weather_max   39102 non-null  object
#  9   dep_weather_desc  39102 non-null  object
#  10  arr_date          39102 non-null  object
#  11  arr_time          39102 non-null  object
#  12  arr_airport_name  39102 non-null  object
#  13  arr_airport_code  39102 non-null  object
#  14  arr_status        39102 non-null  object
#  15  arr_weather_min   39102 non-null  object
# ...

# %%
from tqdm.notebook import tqdm

# %%
vacia = []
for i in tqdm(aena.iterrows()):
    
    if i[1][5] == 'AEI':
        vacia.append(39)
    elif i[1][5] == 'JCU':
        vacia.append(36)
    elif i[1][5] == 'LCG':
        vacia.append(19)
    elif i[1][5] == 'BIO':
        vacia.append(14)
    elif i[1][5] == 'ALC':
        vacia.append(6)
    elif i[1][5] == 'LEI':
        vacia.append(25)
    elif i[1][5] == 'MAD':
        vacia.append(1)
    elif i[1][5] == 'BCN':
        vacia.append(2)
    elif i[1][5] == 'SVQ':
        vacia.append(11)
    elif i[1][5] == 'PMI':
        vacia.append(3)
    elif i[1][5] == 'LEN':
        vacia.append(40)
    elif i[1][5] == 'VIT':
        vacia.append(32)
    elif i[1][5] == 'RJL':
        vacia.append(44)
    elif i[1][5] == 'REU':
        vacia.append(30)
    elif i[1][5] == 'SPC':
        vacia.append(18)
    elif i[1][5] == 'VLL':
        vacia.append(34)
    elif i[1][5] == 'BJZ':
        vacia.append(38)
    elif i[1][5] == 'ZAZ':
        vacia.append(28)
    elif i[1][5] == 'VGO':
        vacia.append(20)
    elif i[1][5] == 'IBZ':
        vacia.append(7)
    elif i[1][5] == 'VLC':
        vacia.append(9)
    elif i[1][5] == 'GMZ':
        vacia.append(35)
    elif i[1][5] == 'TFN':
        vacia.append(10)
    elif i[1][5] == 'TFS':
        vacia.append(8)
    elif i[1][5] == 'AEI':
        vacia.append(39)
    elif i[1][5] == 'GRO':
        vacia.append(26)
    elif i[1][5] == 'MLN':
        vacia.append(24)
    elif i[1][5] == 'OVD':
        vacia.append(17)
    elif i[1][5] == 'SCQ':
        vacia.append(16)
    elif i[1][5] == 'EAS':
        vacia.append(31)
    elif i[1][5] == 'VDE':
        vacia.append(29)
    elif i[1][5] == 'LPA':
        vacia.append(5)
    elif i[1][5] == 'AGP':
        vacia.append(4)
    elif i[1][5] == 'LEI':
        vacia.append(25)
    elif i[1][5] == 'XRY':
        vacia.append(23)
    elif i[1][5] == 'GRX':
        vacia.append(22)
    elif i[1][5] == 'MJV':
        vacia.append(27)
    elif i[1][5] == 'MAH':
        vacia.append(15)
    elif i[1][5] == 'ACE':
        vacia.append(12)
    elif i[1][5] == 'FUE':
        vacia.append(13)
    elif i[1][5] == 'PNA':
        vacia.append(33)
    elif i[1][5] == 'SDR':
        vacia.append(21)
    elif i[1][5] == 'MJV':
        vacia.append(27)
    elif i[1][5] == 'CDT':
        vacia.append(51)
# Out:
# 0it [00:00, ?it/s]

# %%
len(vacia), len(aena)
# Out:
# (39102, 39102)

# %%
aena.id_aeropuerto = vacia

# %%
aena.head()
# Out:
#   flightNumber plane             dep_date  dep_time        dep_airport_name  \
# 0       HTY134   AWH  2018-04-13 00:00:00  10:00:00  ALGECIRAS / HELIPUERTO
# 1       HTY110   AWH  2018-04-13 00:00:00  14:15:00                   CEUTA
# 2       HTY112   AWH  2018-04-13 00:00:00  15:05:00  ALGECIRAS / HELIPUERTO
# 3       HTY114   AWH  2018-04-13 00:00:00  15:35:00  ALGECIRAS / HELIPUERTO
# 4       HTY138   AWH  2018-04-13 00:00:00  18:45:00  ALGECIRAS / HELIPUERTO
#
#   dep_airport_code                         dep_status dep_weather_min  \
# 0              AEI  El vuelo ha despegado a las 10:03               9
# 1              JCU       Llegada prevista a las 14:15              11
# 2              AEI        Salida prevista a las 15:10               9
# 3              AEI        Salida prevista a las 15:40               9
# 4              AEI        Salida prevista a las 18:50               9
#
#   dep_weather_max     dep_weather_desc             arr_date  arr_time  \
# ...

# %%
aena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39102 entries, 0 to 39101
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   flightNumber      39102 non-null  object
#  1   plane             39102 non-null  object
#  2   dep_date          39102 non-null  object
#  3   dep_time          39102 non-null  object
#  4   dep_airport_name  39102 non-null  object
#  5   dep_airport_code  39102 non-null  object
#  6   dep_status        39102 non-null  object
#  7   dep_weather_min   39102 non-null  object
#  8   dep_weather_max   39102 non-null  object
#  9   dep_weather_desc  39102 non-null  object
#  10  arr_date          39102 non-null  object
#  11  arr_time          39102 non-null  object
#  12  arr_airport_name  39102 non-null  object
#  13  arr_airport_code  39102 non-null  object
#  14  arr_status        39102 non-null  object
#  15  arr_weather_min   39102 non-null  object
# ...

# %%
aena.to_excel('vuelos_clean.xlsx', index=False)

# %% [markdown]
# ### Web scraping

# %%
from selenium import webdriver

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import warnings
warnings.filterwarnings('ignore')
import requests

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "C:/Users/bniet/OneDrive/Documentos/GitHub/laboratorios/4.3-lab-web-scraping-selenium/driver/chromedriver.exe" #remember substitute this for your driver path
driver = webdriver.Chrome(driver,options = opciones)

# %%
url = 'https://www.enterat.com/servicios/mapa-aeropuertos-espana.php'

# %%
driver.get(url)
driver.current_url
# Out:
# 'https://www.enterat.com/servicios/mapa-aeropuertos-espana.php'

# %%
tabla = driver.find_element(By.TAG_NAME, 'table')
filas = tabla.find_elements(By.TAG_NAME, 'tr')

data=[]

for f in filas:
    
    elementos=f.find_elements(By.TAG_NAME,'td')
    
    tmp=[]
    
    for e in elementos:
        
        tmp.append(e.text)
        
    data.append(tmp)
    
data
# Out:
# [['', 'Aeropuerto', 'Nº de pasajeros', 'Variación sobre 2020 (%)'],
#  ['1', 'ADOLFO SUÁREZ MADRID-BARAJAS', '24.135.220', '41,0%'],
#  ['2', 'BARCELONA-EL PRAT J.T.', '18.874.896', '48,2%'],
#  ['3', 'PALMA DE MALLORCA', '14.496.857', '137,3%'],
#  ['4', 'MALAGA-COSTA DEL SOL', '8.874.765', '72,0%'],
#  ['5', 'GRAN CANARIA', '6.900.493', '34,4%'],
#  ['6', 'ALICANTE-ELCHE MIGUEL HDEZ.', '5.841.181', '56,2%'],
#  ['7', 'IBIZA', '4.851.819', '129,9%'],
#  ['8', 'TENERIFE-SUR', '4.605.827', '35,8%'],
#  ['9', 'VALENCIA', '4.077.836', '63,9%'],
#  ['10', 'TENERIFE NORTE-C. LA LAGUNA', '3.840.160', '37,3%'],
#  ['11', 'SEVILLA', '3.444.459', '48,7%'],
#  ['12', 'LANZAROTE-CESAR MANRIQUE', '3.438.407', '35,5%'],
#  ['13', 'FUERTEVENTURA', '3.114.107', '45,2%'],
#  ['14', 'BILBAO', '2.580.911', '52,7%'],
#  ['15', 'MENORCA', '2.325.327', '115,9%'],
#  ['16', 'SANTIAGO-ROSALÍA DE CASTRO', '1.653.821', '76,8%'],
#  ['17', 'ASTURIAS', '831.793', '66,7%'],
# ...

# %%
cabeceras=driver.find_element(By.TAG_NAME, 'tr')
cabeceras=[c.text for c in cabeceras.find_elements(By.TAG_NAME,'td')]
driver.quit()
cabeceras
# Out:
# ['', 'Aeropuerto', 'Nº de pasajeros', 'Variación sobre 2020 (%)']

# %%
df=pd.DataFrame(data[1:], columns= cabeceras)
df[:10]
# Out:
#                          Aeropuerto Nº de pasajeros Variación sobre 2020 (%)
# 0   1  ADOLFO SUÁREZ MADRID-BARAJAS      24.135.220                    41,0%
# 1   2        BARCELONA-EL PRAT J.T.      18.874.896                    48,2%
# 2   3             PALMA DE MALLORCA      14.496.857                   137,3%
# 3   4          MALAGA-COSTA DEL SOL       8.874.765                    72,0%
# 4   5                  GRAN CANARIA       6.900.493                    34,4%
# 5   6   ALICANTE-ELCHE MIGUEL HDEZ.       5.841.181                    56,2%
# 6   7                         IBIZA       4.851.819                   129,9%
# 7   8                  TENERIFE-SUR       4.605.827                    35,8%
# 8   9                      VALENCIA       4.077.836                    63,9%
# 9  10   TENERIFE NORTE-C. LA LAGUNA       3.840.160                    37,3%

# %%
"""datos = driver.find_elements(By.TAG_NAME, 'a')
data=[]
for e in datos:
    data.append(e.get_attribute('href'))
data[38:68]
"""
# Out:
# "datos = driver.find_elements(By.TAG_NAME, 'a')\ndata=[]\nfor e in datos:\n    data.append(e.get_attribute('href'))\ndata[38:68]\n"

# %%
#pd.read_excel('https://www.datosmundial.com/europa/espana/aeropuertos.php#LEBL')

# %% [markdown]
# ### Renombrar columnas

# %%
df.columns
# Out:
# Index(['', 'Aeropuerto', 'Nº de pasajeros', 'Variación sobre 2020 (%)'], dtype='object')

# %%
new_cols = [c.lower().rstrip().lstrip().replace(' ', '_') for c in df.columns]
new_cols
# Out:
# ['', 'aeropuerto', 'nº_de_pasajeros', 'variación_sobre_2020_(%)']

# %%
dict(zip(df.columns, new_cols))
# Out:
# {'': '',
#  'Aeropuerto': 'aeropuerto',
#  'Nº de pasajeros': 'nº_de_pasajeros',
#  'Variación sobre 2020 (%)': 'variación_sobre_2020_(%)'}

# %%
df = df.rename(columns={k:v for k,v in zip(df.columns, new_cols)})

# %%
df.head()
# Out:
#                         aeropuerto nº_de_pasajeros variación_sobre_2020_(%)
# 0  1  ADOLFO SUÁREZ MADRID-BARAJAS      24.135.220                    41,0%
# 1  2        BARCELONA-EL PRAT J.T.      18.874.896                    48,2%
# 2  3             PALMA DE MALLORCA      14.496.857                   137,3%
# 3  4          MALAGA-COSTA DEL SOL       8.874.765                    72,0%
# 4  5                  GRAN CANARIA       6.900.493                    34,4%

# %%
df.columns= ['id_aeropuerto', 'aeropuerto', 'nº_de_pasajeros','variación_sobre_2020_(%)']

# %%
df
# Out:
#    id_aeropuerto                               aeropuerto nº_de_pasajeros  \
# 0              1             ADOLFO SUÁREZ MADRID-BARAJAS      24.135.220
# 1              2                   BARCELONA-EL PRAT J.T.      18.874.896
# 2              3                        PALMA DE MALLORCA      14.496.857
# 3              4                     MALAGA-COSTA DEL SOL       8.874.765
# 4              5                             GRAN CANARIA       6.900.493
# 5              6              ALICANTE-ELCHE MIGUEL HDEZ.       5.841.181
# 6              7                                    IBIZA       4.851.819
# 7              8                             TENERIFE-SUR       4.605.827
# 8              9                                 VALENCIA       4.077.836
# 9             10              TENERIFE NORTE-C. LA LAGUNA       3.840.160
# 10            11                                  SEVILLA       3.444.459
# 11            12                 LANZAROTE-CESAR MANRIQUE       3.438.407
# ...

# %% [markdown]
# ### Subir las tablas a la base de datos

# %%
# %pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
#lenguaje+driver://usuario:password@servidor:puerto/database   (string de conexion)

airlines='mysql+pymysql://root:1234@localhost:3306/airlines'

cursor=create_engine(airlines)

# %%
satisfaction=pd.read_csv('train_clean.csv')

satisfaction.to_sql(name='satisfaction', con=cursor, if_exists='replace', index=False)
# Out:
# 103594

# %%
info_vuelos=pd.read_excel('vuelos_clean.xlsx')

info_vuelos.to_sql(name='aena', con=cursor, if_exists='replace', index=False)
# Out:
# 39102

# %%
df.to_sql(name='aeropuertos', con=cursor, if_exists='replace', index=False)
# Out:
# 50
